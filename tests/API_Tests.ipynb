# %%
import requests
import pandas as pd

base_url = 'https://at-data-driven-apps-com-python.onrender.com/sb/'

# %%
test_status = requests.get(base_url)
print(test_status.status_code)
# Out:
# 200

# %%
test_match = requests.get(base_url + 'match', params={'match_id': 3895302})
pd.DataFrame(test_match.json())
# Out:
#      50_50 bad_behaviour_card ball_receipt_outcome  \
# 0      N/A                N/A                  N/A
# 1      N/A                N/A                  N/A
# 2      N/A                N/A                  N/A
# 3      N/A                N/A                  N/A
# 4      N/A                N/A                  N/A
# ...    ...                ...                  ...
# 4218   N/A        Yellow Card                  N/A
# 4219   N/A        Yellow Card                  N/A
# 4220   N/A                N/A                  N/A
# 4221   N/A                N/A                  N/A
# 4222   N/A                N/A                  N/A
#
#      ball_recovery_recovery_failure block_deflection block_save_block  \
# 0                               N/A              N/A              N/A
# 1                               N/A              N/A              N/A
# 2                               N/A              N/A              N/A
# ...

# %%
test_get_main_events = requests.get(base_url + 'match_main_events', params={'match_id': 3895302})
pd.DataFrame(test_get_main_events.json())
# Out:
#               type  minute              team                       player  \
# 0             Pass      59  Bayer Leverkusen         Victor Okoh Boniface
# 1             Pass      67  Bayer Leverkusen               Robert Andrich
# 2             Pass      82  Bayer Leverkusen  Exequiel Alejandro Palacios
# 3             Pass      89  Bayer Leverkusen    Alejandro Grimaldo García
# 4          Dribble       2     Werder Bremen                Romano Schmid
# ..             ...     ...               ...                          ...
# 102   Substitution      75  Bayer Leverkusen  Piero Martín Hincapié Reyna
# 103   Substitution      76     Werder Bremen         Leonardo Bittencourt
# 104   Substitution      76  Bayer Leverkusen                 Granit Xhaka
# 105  Bad Behaviour      46     Werder Bremen         Leonardo Bittencourt
# 106  Bad Behaviour      46  Bayer Leverkusen  Piero Martín Hincapié Reyna
#
#                     position bad_behaviour_card dribble_outcome  \
# ...

# %%
test_match_players = requests.get(base_url + 'match_players', params={'match_id': 3895302})
pd.DataFrame(test_match_players.json())
# Out:
#    player_id                       player              team
# 0        N/A                          N/A  Bayer Leverkusen
# 1        N/A                          N/A     Werder Bremen
# 2    34870.0               Nick Woltemade     Werder Bremen
# 3    12299.0               Marvin Ducksch     Werder Bremen
# 4    31100.0               Christian Groß     Werder Bremen
# 5    51769.0              Julián Malatini     Werder Bremen
# 6     8576.0              Mitchell Weiser     Werder Bremen
# 7    41411.0                 Nathan Tella  Bayer Leverkusen
# 8     8667.0               Lukáš Hrádecký  Bayer Leverkusen
# 9    30606.0        Edmond Fayçal Tapsoba  Bayer Leverkusen
# 10    9195.0               Robert Andrich  Bayer Leverkusen
# 11    8221.0                 Jonathan Tah  Bayer Leverkusen
# 12   27133.0              Odilon Kossonou  Bayer Leverkusen
# 13    3500.0                 Granit Xhaka  Bayer Leverkusen
# 14   32289.0         Victor Okoh Boniface  Bayer Leverkusen
# ...

# %%
test_match_summary = requests.get(base_url + 'match_summary', params={'match_id': 3895302})
test_match_summary.json()
# Out:
# {'match_summary': '**Bayer Leverkusen vence o Werder Bremen em jogo emocionante**\n\nEm uma partida eletrizante no Estádio BayArena, o Bayer Leverkusen superou o Werder Bremen por 4 a 0, em um jogo marcado por gols importantes e diversas oportunidades de ambos os lados.\n\nO Leverkusen abriu o placar aos 24 minutos com um golaço de Victor Boniface. O time da casa dominou a maior parte do primeiro tempo, criando diversas chances de gol, mas parando nas defesas do goleiro do Bremen e em alguns lances de azar. O Werder Bremen também teve suas chances, mas não conseguiu superar a defesa do Leverkusen.\n\nO segundo tempo começou com o mesmo ritmo frenético. Aos 59 minutos, Boniface deu uma assistência para Xhaka ampliar o placar.  O Leverkusen continuou pressionando e aos 67 minutos, Andrich fez mais uma assistência, dessa vez para Wirtz marcar o terceiro gol.  Palacios e Grimaldo também contribuíram com assistências nos gols seguintes, mostrando a força coletiva do time. Wirtz, que entro
# ...

# %%
test_player_profile = requests.get(base_url + 'player_profile', params={'match_id': 3895302,'player_id': 40724})
pd.DataFrame([test_player_profile.json()])
# Out:
#          jogador                  posicao  total_passes  total_chutes  \
# 0  Florian Wirtz  Left Attacking Midfield            27             5
#
#    total_dribles  total_interceptacoes  total_faltas  total_cartoes_amarelos  \
# 0              3                     2             1                       0
#
#    total_cartoes_vermelhos  total_gols  ...  taxa_assistencias  taxa_dribles  \
# 0                        0           3  ...                0.0          0.33
#
#    passes_por_minuto  chutes_por_minuto  dribles_por_minuto  \
# 0               0.61               0.11                0.07
#
#    interceptacoes_por_minuto  faltas_por_minuto  total_recuperacoes  \
# 0                       0.05               0.02                   4
#
#    total_recebimentos  total_mal_comportamento
# 0                  37                        0
#
# [1 rows x 25 columns]
